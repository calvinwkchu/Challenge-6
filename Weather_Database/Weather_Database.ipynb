# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_weather_url = url + "&q=" + "yendi"
city_weather = requests.get(city_weather_url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | steamboat springs
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 1 | mokokchung
# Processing Record 7 of Set 1 | mangaratiba
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | atar
# Processing Record 10 of Set 1 | sinnamary
# Processing Record 11 of Set 1 | najran
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | san rafael
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | kosice
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | souillac
# Processing Record 18 of Set 1 | krasnoselkup
# Processing Record 19 of Set 1 | risaralda
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | evensk
# Processing Record 22 of Set 1 | muroto
# Processing Record 23 of Set 1 | kazachinskoye
# Processing Record 24 of Set 1 | mombris
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | vetluzhskiy
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | grindavik
# Processing Record 30 of Set 1 | bokspits
# City not found. Skipping...
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | saint-georges
# Processing Record 33 of Set 1 | bahir dar
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | jutai
# Processing Record 36 of Set 1 | namibe
# Processing Record 37 of Set 1 | chachapoyas
# Processing Record 38 of Set 1 | muros
# Processing Record 39 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 1 | saint anthony
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | faanui
# Processing Record 45 of Set 1 | naze
# Processing Record 46 of Set 1 | honningsvag
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | faya
# Processing Record 49 of Set 1 | margate
# Processing Record 50 of Set 1 | oksfjord
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 3 of Set 2 | namatanai
# Processing Record 4 of Set 2 | kondinskoye
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | chapais
# Processing Record 7 of Set 2 | manggar
# Processing Record 8 of Set 2 | uglich
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | severo-yeniseyskiy
# Processing Record 11 of Set 2 | sakakah
# Processing Record 12 of Set 2 | ullapool
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | touros
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | amga
# Processing Record 18 of Set 2 | erenhot
# Processing Record 19 of Set 2 | qidong
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | cherskiy
# Processing Record 22 of Set 2 | bilibino
# Processing Record 23 of Set 2 | cherepovets
# Processing Record 24 of Set 2 | suez
# Processing Record 25 of Set 2 | novikovo
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | trapani
# Processing Record 28 of Set 2 | constitucion
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | sao francisco
# Processing Record 31 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 2 | cap malheureux
# Processing Record 33 of Set 2 | vieux-habitants
# Processing Record 34 of Set 2 | kahului
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | bensonville
# Processing Record 38 of Set 2 | beringovskiy
# Processing Record 39 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 2 | ransang
# Processing Record 41 of Set 2 | ust-maya
# Processing Record 42 of Set 2 | naples
# Processing Record 43 of Set 2 | fasa
# Processing Record 44 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 2 | leningradskiy
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | aykhal
# Processing Record 48 of Set 2 | roald
# Processing Record 49 of Set 2 | mount isa
# Processing Record 50 of Set 2 | laguna
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | lasa
# Processing Record 4 of Set 3 | bandarbeyla
# Processing Record 5 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | hun
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | antalaha
# Processing Record 11 of Set 3 | nobeoka
# Processing Record 12 of Set 3 | sao joao da barra
# Processing Record 13 of Set 3 | lorengau
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | udaipura
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 3 | codrington
# Processing Record 19 of Set 3 | vila
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | iqaluit
# Processing Record 22 of Set 3 | ulladulla
# Processing Record 23 of Set 3 | arraial do cabo
# Processing Record 24 of Set 3 | chhatarpur
# Processing Record 25 of Set 3 | lazaro cardenas
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | ahipara
# Processing Record 28 of Set 3 | vao
# Processing Record 29 of Set 3 | pevek
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | zhigansk
# Processing Record 32 of Set 3 | caconda
# Processing Record 33 of Set 3 | north bend
# Processing Record 34 of Set 3 | longyearbyen
# Processing Record 35 of Set 3 | belmonte
# Processing Record 36 of Set 3 | gua musang
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | jerome
# Processing Record 39 of Set 3 | abha
# Processing Record 40 of Set 3 | saint-joseph
# Processing Record 41 of Set 3 | klaksvik
# Processing Record 42 of Set 3 | sioux lookout
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | coquimbo
# Processing Record 45 of Set 3 | lakes entrance
# Processing Record 46 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 3 | omsukchan
# Processing Record 48 of Set 3 | tarboro
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | lagoa
# Processing Record 2 of Set 4 | phan thiet
# Processing Record 3 of Set 4 | hamilton
# Processing Record 4 of Set 4 | hobart
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | tokmak
# Processing Record 7 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 4 | kruisfontein
# Processing Record 9 of Set 4 | tuatapere
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | kieta
# Processing Record 12 of Set 4 | deh rawud
# City not found. Skipping...
# Processing Record 13 of Set 4 | vardo
# Processing Record 14 of Set 4 | tevaitoa
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | llandrindod wells
# Processing Record 17 of Set 4 | norman wells
# Processing Record 18 of Set 4 | half moon bay
# Processing Record 19 of Set 4 | toftir
# City not found. Skipping...
# Processing Record 20 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 4 | portland
# Processing Record 22 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 4 | murakami
# Processing Record 24 of Set 4 | narsaq
# Processing Record 25 of Set 4 | avarua
# Processing Record 26 of Set 4 | saint-louis
# Processing Record 27 of Set 4 | san cristobal
# Processing Record 28 of Set 4 | hede
# Processing Record 29 of Set 4 | forlev
# Processing Record 30 of Set 4 | witney
# Processing Record 31 of Set 4 | los llanos de aridane
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | shelburne
# Processing Record 34 of Set 4 | itoman
# Processing Record 35 of Set 4 | bongandanga
# Processing Record 36 of Set 4 | deputatskiy
# Processing Record 37 of Set 4 | itarema
# Processing Record 38 of Set 4 | provideniya
# Processing Record 39 of Set 4 | hutchinson
# Processing Record 40 of Set 4 | tome-acu
# City not found. Skipping...
# Processing Record 41 of Set 4 | zambezi
# Processing Record 42 of Set 4 | gitega
# Processing Record 43 of Set 4 | coalinga
# Processing Record 44 of Set 4 | bredy
# Processing Record 45 of Set 4 | lompoc
# Processing Record 46 of Set 4 | wexford
# Processing Record 47 of Set 4 | weymouth
# Processing Record 48 of Set 4 | nelson bay
# Processing Record 49 of Set 4 | kashi
# Processing Record 50 of Set 4 | pyaozerskiy
# Processing Record 1 of Set 5 | dingle
# Processing Record 2 of Set 5 | zlynka
# Processing Record 3 of Set 5 | boende
# Processing Record 4 of Set 5 | new norfolk
# Processing Record 5 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 5 | kirksville
# Processing Record 7 of Set 5 | hami
# Processing Record 8 of Set 5 | bundaberg
# Processing Record 9 of Set 5 | thompson
# Processing Record 10 of Set 5 | beinamar
# Processing Record 11 of Set 5 | plettenberg bay
# Processing Record 12 of Set 5 | srednekolymsk
# Processing Record 13 of Set 5 | mackay
# Processing Record 14 of Set 5 | kamenka
# Processing Record 15 of Set 5 | buchanan
# Processing Record 16 of Set 5 | high level
# Processing Record 17 of Set 5 | beloha
# Processing Record 18 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 5 | kytlym
# City not found. Skipping...
# Processing Record 20 of Set 5 | hithadhoo
# Processing Record 21 of Set 5 | lavrentiya
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | alofi
# Processing Record 24 of Set 5 | cayenne
# Processing Record 25 of Set 5 | chandler
# Processing Record 26 of Set 5 | khyriv
# Processing Record 27 of Set 5 | pajapan
# Processing Record 28 of Set 5 | qaqortoq
# Processing Record 29 of Set 5 | airai
# Processing Record 30 of Set 5 | severo-kurilsk
# Processing Record 31 of Set 5 | rubidoux
# Processing Record 32 of Set 5 | richards bay
# Processing Record 33 of Set 5 | comodoro rivadavia
# Processing Record 34 of Set 5 | solnechnyy
# Processing Record 35 of Set 5 | nelidovo
# Processing Record 36 of Set 5 | chenzhou
# Processing Record 37 of Set 5 | graneros
# Processing Record 38 of Set 5 | howard springs
# Processing Record 39 of Set 5 | malindi
# Processing Record 40 of Set 5 | huejuquilla el alto
# Processing Record 41 of Set 5 | angoche
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | casma
# Processing Record 44 of Set 5 | marawi
# Processing Record 45 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 5 | billings
# Processing Record 47 of Set 5 | payo
# Processing Record 48 of Set 5 | troyes
# Processing Record 49 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 5 | barrow
# Processing Record 1 of Set 6 | acin
# City not found. Skipping...
# Processing Record 2 of Set 6 | russell
# Processing Record 3 of Set 6 | hovd
# Processing Record 4 of Set 6 | yershov
# Processing Record 5 of Set 6 | cidreira
# Processing Record 6 of Set 6 | manadhoo
# Processing Record 7 of Set 6 | san patricio
# Processing Record 8 of Set 6 | kenai
# Processing Record 9 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | mahebourg
# Processing Record 12 of Set 6 | victoria
# Processing Record 13 of Set 6 | tocopilla
# Processing Record 14 of Set 6 | santa rosa
# Processing Record 15 of Set 6 | karambakkudi
# Processing Record 16 of Set 6 | chiplun
# Processing Record 17 of Set 6 | oltu
# Processing Record 18 of Set 6 | kaeo
# Processing Record 19 of Set 6 | zhengjiatun
# Processing Record 20 of Set 6 | hofn
# Processing Record 21 of Set 6 | itaituba
# Processing Record 22 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 6 | okhotsk
# Processing Record 24 of Set 6 | lakeside
# Processing Record 25 of Set 6 | redmond
# Processing Record 26 of Set 6 | coihaique
# Processing Record 27 of Set 6 | dezhou
# Processing Record 28 of Set 6 | cururupu
# Processing Record 29 of Set 6 | manta
# Processing Record 30 of Set 6 | monrovia
# Processing Record 31 of Set 6 | xai-xai
# Processing Record 32 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 6 | dhidhdhoo
# Processing Record 34 of Set 6 | serenje
# Processing Record 35 of Set 6 | talavera de la reina
# Processing Record 36 of Set 6 | komsomolskiy
# Processing Record 37 of Set 6 | hokitika
# Processing Record 38 of Set 6 | dombarovskiy
# Processing Record 39 of Set 6 | cravo norte
# Processing Record 40 of Set 6 | esperance
# Processing Record 41 of Set 6 | berezovyy
# Processing Record 42 of Set 6 | penzance
# Processing Record 43 of Set 6 | hasaki
# Processing Record 44 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 45 of Set 6 | tilichiki
# Processing Record 46 of Set 6 | mazara del vallo
# Processing Record 47 of Set 6 | sao sebastiao
# Processing Record 48 of Set 6 | galle
# Processing Record 49 of Set 6 | sayyan
# Processing Record 50 of Set 6 | tessalit
# Processing Record 1 of Set 7 | havre-saint-pierre
# Processing Record 2 of Set 7 | palma di montechiaro
# Processing Record 3 of Set 7 | ambon
# Processing Record 4 of Set 7 | mahajanga
# Processing Record 5 of Set 7 | alice springs
# Processing Record 6 of Set 7 | avera
# Processing Record 7 of Set 7 | port lincoln
# Processing Record 8 of Set 7 | sitka
# Processing Record 9 of Set 7 | bengkulu
# Processing Record 10 of Set 7 | riyadh
# Processing Record 11 of Set 7 | camacari
# Processing Record 12 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 13 of Set 7 | christchurch
# Processing Record 14 of Set 7 | nouadhibou
# Processing Record 15 of Set 7 | valdivia
# Processing Record 16 of Set 7 | manokwari
# Processing Record 17 of Set 7 | tautira
# Processing Record 18 of Set 7 | matara
# Processing Record 19 of Set 7 | iberia
# Processing Record 20 of Set 7 | shingu
# Processing Record 21 of Set 7 | jardim
# Processing Record 22 of Set 7 | callaway
# Processing Record 23 of Set 7 | sambava
# Processing Record 24 of Set 7 | uvinza
# Processing Record 25 of Set 7 | andros town
# Processing Record 26 of Set 7 | lichinga
# Processing Record 27 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 28 of Set 7 | alto araguaia
# Processing Record 29 of Set 7 | san quintin
# Processing Record 30 of Set 7 | praia da vitoria
# Processing Record 31 of Set 7 | gat
# Processing Record 32 of Set 7 | champerico
# Processing Record 33 of Set 7 | yenagoa
# Processing Record 34 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | anloga
# Processing Record 36 of Set 7 | kalabo
# Processing Record 37 of Set 7 | bendigo
# Processing Record 38 of Set 7 | broken hill
# Processing Record 39 of Set 7 | meulaboh
# Processing Record 40 of Set 7 | derzhavinsk
# Processing Record 41 of Set 7 | khani
# Processing Record 42 of Set 7 | waingapu
# Processing Record 43 of Set 7 | mackenzie
# Processing Record 44 of Set 7 | bethel
# Processing Record 45 of Set 7 | ponta do sol
# Processing Record 46 of Set 7 | poum
# Processing Record 47 of Set 7 | hostotipaquillo
# Processing Record 48 of Set 7 | katha
# City not found. Skipping...
# Processing Record 49 of Set 7 | shache
# Processing Record 50 of Set 7 | beyneu
# Processing Record 1 of Set 8 | awjilah
# Processing Record 2 of Set 8 | rio gallegos
# Processing Record 3 of Set 8 | amot
# Processing Record 4 of Set 8 | el tigre
# Processing Record 5 of Set 8 | magistralnyy
# Processing Record 6 of Set 8 | lawton
# Processing Record 7 of Set 8 | katobu
# Processing Record 8 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 8 | rozivka
# Processing Record 10 of Set 8 | middlebury
# Processing Record 11 of Set 8 | plastun
# Processing Record 12 of Set 8 | padang
# Processing Record 13 of Set 8 | klaeng
# Processing Record 14 of Set 8 | canto do buriti
# Processing Record 15 of Set 8 | lidkoping
# Processing Record 16 of Set 8 | dvubratskiy
# Processing Record 17 of Set 8 | barra do garcas
# Processing Record 18 of Set 8 | tabuleiro do norte
# Processing Record 19 of Set 8 | nome
# Processing Record 20 of Set 8 | nikolayevskaya
# Processing Record 21 of Set 8 | wichita falls
# Processing Record 22 of Set 8 | muravlenko
# Processing Record 23 of Set 8 | fengrun
# Processing Record 24 of Set 8 | riacho de santana
# Processing Record 25 of Set 8 | nanortalik
# Processing Record 26 of Set 8 | brookhaven
# Processing Record 27 of Set 8 | san juan
# Processing Record 28 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 29 of Set 8 | egvekinot
# Processing Record 30 of Set 8 | luyang
# Processing Record 31 of Set 8 | marsa matruh
# Processing Record 32 of Set 8 | arman
# Processing Record 33 of Set 8 | bilma
# Processing Record 34 of Set 8 | tiksi
# Processing Record 35 of Set 8 | clyde river
# Processing Record 36 of Set 8 | aybak
# City not found. Skipping...
# Processing Record 37 of Set 8 | kaitangata
# Processing Record 38 of Set 8 | ancud
# Processing Record 39 of Set 8 | haines junction
# Processing Record 40 of Set 8 | buta
# Processing Record 41 of Set 8 | teya
# Processing Record 42 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 8 | sur
# Processing Record 44 of Set 8 | atambua
# Processing Record 45 of Set 8 | bairiki
# Processing Record 46 of Set 8 | pocatello
# Processing Record 47 of Set 8 | kuryk
# Processing Record 48 of Set 8 | signagi
# City not found. Skipping...
# Processing Record 49 of Set 8 | ewa beach
# Processing Record 50 of Set 8 | aklavik
# Processing Record 1 of Set 9 | isangel
# Processing Record 2 of Set 9 | embu
# Processing Record 3 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 9 | cherlak
# Processing Record 5 of Set 9 | pacific grove
# Processing Record 6 of Set 9 | boddam
# Processing Record 7 of Set 9 | haverfordwest
# Processing Record 8 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 9 | pemangkat
# Processing Record 10 of Set 9 | maniitsoq
# Processing Record 11 of Set 9 | vilyuysk
# Processing Record 12 of Set 9 | yumen
# Processing Record 13 of Set 9 | genhe
# Processing Record 14 of Set 9 | timberlake
# Processing Record 15 of Set 9 | tura
# Processing Record 16 of Set 9 | keshan
# City not found. Skipping...
# Processing Record 17 of Set 9 | teguise
# Processing Record 18 of Set 9 | porto santo
# Processing Record 19 of Set 9 | san carlos de bariloche
# Processing Record 20 of Set 9 | savelugu
# Processing Record 21 of Set 9 | taybad
# Processing Record 22 of Set 9 | cabo san lucas
# Processing Record 23 of Set 9 | nuevo progreso
# Processing Record 24 of Set 9 | fukue
# Processing Record 25 of Set 9 | yunyang
# Processing Record 26 of Set 9 | hirara
# Processing Record 27 of Set 9 | zhangye
# Processing Record 28 of Set 9 | ambanja
# Processing Record 29 of Set 9 | emerald
# Processing Record 30 of Set 9 | cap-aux-meules
# Processing Record 31 of Set 9 | roblin
# Processing Record 32 of Set 9 | ahuimanu
# Processing Record 33 of Set 9 | husavik
# Processing Record 34 of Set 9 | beira
# Processing Record 35 of Set 9 | deniliquin
# Processing Record 36 of Set 9 | bambous virieux
# Processing Record 37 of Set 9 | steinbach
# Processing Record 38 of Set 9 | seydi
# Processing Record 39 of Set 9 | kinsale
# Processing Record 40 of Set 9 | lata
# Processing Record 41 of Set 9 | vestmanna
# Processing Record 42 of Set 9 | kautokeino
# Processing Record 43 of Set 9 | hayden
# Processing Record 44 of Set 9 | paracuru
# Processing Record 45 of Set 9 | quatre cocos
# Processing Record 46 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 9 | nehe
# Processing Record 48 of Set 9 | conde
# Processing Record 49 of Set 9 | shrigonda
# Processing Record 50 of Set 9 | sola
# Processing Record 1 of Set 10 | sao jose da coroa grande
# Processing Record 2 of Set 10 | talnakh
# Processing Record 3 of Set 10 | konevo
# Processing Record 4 of Set 10 | omboue
# Processing Record 5 of Set 10 | saldanha
# Processing Record 6 of Set 10 | hastings
# Processing Record 7 of Set 10 | sorland
# Processing Record 8 of Set 10 | santarem
# Processing Record 9 of Set 10 | saint george
# Processing Record 10 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 11 of Set 10 | bloemhof
# Processing Record 12 of Set 10 | port hawkesbury
# Processing Record 13 of Set 10 | trabzon
# Processing Record 14 of Set 10 | clinton
# Processing Record 15 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 10 | dedza
# Processing Record 17 of Set 10 | seddon
# Processing Record 18 of Set 10 | palora
# Processing Record 19 of Set 10 | paciran
# Processing Record 20 of Set 10 | neuquen
# Processing Record 21 of Set 10 | luderitz
# Processing Record 22 of Set 10 | prabumulih
# Processing Record 23 of Set 10 | souda
# Processing Record 24 of Set 10 | dumas
# Processing Record 25 of Set 10 | tabou
# Processing Record 26 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 10 | bulgan
# Processing Record 28 of Set 10 | usinsk
# Processing Record 29 of Set 10 | aurora
# Processing Record 30 of Set 10 | sale
# Processing Record 31 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 10 | olinda
# Processing Record 33 of Set 10 | bokajan
# Processing Record 34 of Set 10 | kant
# Processing Record 35 of Set 10 | sogdiondon
# City not found. Skipping...
# Processing Record 36 of Set 10 | salinopolis
# Processing Record 37 of Set 10 | albuquerque
# Processing Record 38 of Set 10 | mayor pablo lagerenza
# Processing Record 39 of Set 10 | san carlos
# Processing Record 40 of Set 10 | stornoway
# Processing Record 41 of Set 10 | eureka
# Processing Record 42 of Set 10 | vila franca do campo
# Processing Record 43 of Set 10 | wasilla
# Processing Record 44 of Set 10 | popondetta
# Processing Record 45 of Set 10 | bathsheba
# Processing Record 46 of Set 10 | maceio
# Processing Record 47 of Set 10 | havelock
# Processing Record 48 of Set 10 | san rafael del sur
# Processing Record 49 of Set 10 | voi
# Processing Record 50 of Set 10 | puerto madryn
# Processing Record 1 of Set 11 | sri aman
# Processing Record 2 of Set 11 | viedma
# Processing Record 3 of Set 11 | nhulunbuy
# Processing Record 4 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 11 | sao filipe
# Processing Record 6 of Set 11 | fairbanks
# Processing Record 7 of Set 11 | kasempa
# Processing Record 8 of Set 11 | camacha
# Processing Record 9 of Set 11 | huescar
# Processing Record 10 of Set 11 | rocha
# Processing Record 11 of Set 11 | mansa
# Processing Record 12 of Set 11 | mehamn
# Processing Record 13 of Set 11 | kargasok
# Processing Record 14 of Set 11 | chicama
# Processing Record 15 of Set 11 | yaan
# Processing Record 16 of Set 11 | lopsmarka
# Processing Record 17 of Set 11 | batemans bay
# Processing Record 18 of Set 11 | atbasar
# Processing Record 19 of Set 11 | ninghai
# Processing Record 20 of Set 11 | guymon
# Processing Record 21 of Set 11 | port-cartier
# Processing Record 22 of Set 11 | rawson
# Processing Record 23 of Set 11 | ishim
# Processing Record 24 of Set 11 | dukat
# Processing Record 25 of Set 11 | korla
# Processing Record 26 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 11 | pavilosta
# Processing Record 28 of Set 11 | jinchang
# Processing Record 29 of Set 11 | rundu
# Processing Record 30 of Set 11 | mareeba
# Processing Record 31 of Set 11 | yeltsovka
# City not found. Skipping...
# Processing Record 32 of Set 11 | yulara
# Processing Record 33 of Set 11 | lamesa
# Processing Record 34 of Set 11 | nampula
# Processing Record 35 of Set 11 | olafsvik
# Processing Record 36 of Set 11 | novobureyskiy
# Processing Record 37 of Set 11 | goderich
# Processing Record 38 of Set 11 | kawalu
# Processing Record 39 of Set 11 | hambantota
# Processing Record 40 of Set 11 | mombasa
# Processing Record 41 of Set 11 | gazojak
# Processing Record 42 of Set 11 | khash
# Processing Record 43 of Set 11 | maarianhamina
# Processing Record 44 of Set 11 | nabire
# Processing Record 45 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 46 of Set 11 | krasnyy oktyabr
# Processing Record 47 of Set 11 | doha
# Processing Record 48 of Set 11 | wanning
# Processing Record 49 of Set 11 | mount gambier
# Processing Record 50 of Set 11 | grand gaube
# Processing Record 1 of Set 12 | otradnaya
# Processing Record 2 of Set 12 | halmstad
# Processing Record 3 of Set 12 | hukuntsi
# Processing Record 4 of Set 12 | alta floresta
# Processing Record 5 of Set 12 | cullman
# Processing Record 6 of Set 12 | la ronge
# Processing Record 7 of Set 12 | brecksville
# Processing Record 8 of Set 12 | kavaratti
# Processing Record 9 of Set 12 | price
# Processing Record 10 of Set 12 | werda
# Processing Record 11 of Set 12 | soloneshnoye
# Processing Record 12 of Set 12 | macusani
# Processing Record 13 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 14 of Set 12 | barra patuca
# Processing Record 15 of Set 12 | jalu
# Processing Record 16 of Set 12 | villarrica
# Processing Record 17 of Set 12 | okahandja
# Processing Record 18 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 12 | pishin
# Processing Record 20 of Set 12 | sept-iles
# Processing Record 21 of Set 12 | paita
# Processing Record 22 of Set 12 | krasnopillya
# Processing Record 23 of Set 12 | vila do maio
# Processing Record 24 of Set 12 | lieksa
# Processing Record 25 of Set 12 | buala
# Processing Record 26 of Set 12 | matane
# Processing Record 27 of Set 12 | ust-ishim
# Processing Record 28 of Set 12 | saskylakh
# Processing Record 29 of Set 12 | thinadhoo
# Processing Record 30 of Set 12 | novo aripuana
# Processing Record 31 of Set 12 | juxian
# City not found. Skipping...
# Processing Record 32 of Set 12 | choix
# Processing Record 33 of Set 12 | kapoeta
# Processing Record 34 of Set 12 | portimao
# Processing Record 35 of Set 12 | gobabis
# Processing Record 36 of Set 12 | minab
# Processing Record 37 of Set 12 | manitouwadge
# Processing Record 38 of Set 12 | yauya
# Processing Record 39 of Set 12 | ostrovnoy
# Processing Record 40 of Set 12 | geraldton
# Processing Record 41 of Set 12 | mukhen
# Processing Record 42 of Set 12 | shakhtinsk
# Processing Record 43 of Set 12 | panzhihua
# Processing Record 44 of Set 12 | wagga wagga
# Processing Record 45 of Set 12 | tagusao
# Processing Record 46 of Set 12 | armidale
# Processing Record 47 of Set 12 | tomatlan
# Processing Record 48 of Set 12 | zyryanka
# Processing Record 49 of Set 12 | anito
# Processing Record 50 of Set 12 | gravdal
# Processing Record 1 of Set 13 | catamarca
# Processing Record 2 of Set 13 | langsa
# Processing Record 3 of Set 13 | ammon
# Processing Record 4 of Set 13 | barinas
# Processing Record 5 of Set 13 | oka
# Processing Record 6 of Set 13 | merauke
# Processing Record 7 of Set 13 | valley city
# Processing Record 8 of Set 13 | adiake
# Processing Record 9 of Set 13 | marl
# Processing Record 10 of Set 13 | lovozero
# Processing Record 11 of Set 13 | deer lake
# Processing Record 12 of Set 13 | chingirlau
# Processing Record 13 of Set 13 | malanje
# Processing Record 14 of Set 13 | talaya
# Processing Record 15 of Set 13 | flinders
# Processing Record 16 of Set 13 | zhangjiakou
# Processing Record 17 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 13 | henties bay
# Processing Record 19 of Set 13 | tibati
# Processing Record 20 of Set 13 | tilzapotla
# Processing Record 21 of Set 13 | chinchani
# Processing Record 22 of Set 13 | atherton
# Processing Record 23 of Set 13 | casper
# Processing Record 24 of Set 13 | kumylzhenskaya
# Processing Record 25 of Set 13 | oranjestad
# Processing Record 26 of Set 13 | sisimiut
# Processing Record 27 of Set 13 | ballina
# Processing Record 28 of Set 13 | montorio al vomano
# Processing Record 29 of Set 13 | xichang
# Processing Record 30 of Set 13 | skjervoy
# Processing Record 31 of Set 13 | marsh harbour
# Processing Record 32 of Set 13 | kamiiso
# Processing Record 33 of Set 13 | panjwin
# City not found. Skipping...
# Processing Record 34 of Set 13 | guayaramerin
# Processing Record 35 of Set 13 | broome
# Processing Record 36 of Set 13 | zonguldak
# Processing Record 37 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 38 of Set 13 | gonbad-e qabus
# Processing Record 39 of Set 13 | wangqing
# Processing Record 40 of Set 13 | elizabeth city
# Processing Record 41 of Set 13 | soe
# Processing Record 42 of Set 13 | ketchikan
# Processing Record 43 of Set 13 | niksic
# Processing Record 44 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 13 | sayat
# Processing Record 46 of Set 13 | makakilo city
# Processing Record 47 of Set 13 | urambo
# Processing Record 48 of Set 13 | erzin
# Processing Record 49 of Set 13 | port keats
# Processing Record 50 of Set 13 | kysyl-syr
# Processing Record 1 of Set 14 | paamiut
# Processing Record 2 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 14 | peabiru
# Processing Record 4 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 14 | keokuk
# Processing Record 6 of Set 14 | torremolinos
# Processing Record 7 of Set 14 | seoul
# Processing Record 8 of Set 14 | dunedin
# Processing Record 9 of Set 14 | yagodnoye
# Processing Record 10 of Set 14 | novobirilyussy
# Processing Record 11 of Set 14 | miyazu
# Processing Record 12 of Set 14 | salalah
# Processing Record 13 of Set 14 | san francisco
# Processing Record 14 of Set 14 | phalodi
# Processing Record 15 of Set 14 | paro
# Processing Record 16 of Set 14 | lugovskiy
# City not found. Skipping...
# Processing Record 17 of Set 14 | asau
# Processing Record 18 of Set 14 | stirion
# Processing Record 19 of Set 14 | yuanping
# Processing Record 20 of Set 14 | khuzhir
# Processing Record 21 of Set 14 | visp
# Processing Record 22 of Set 14 | gamba
# Processing Record 23 of Set 14 | pangody
# Processing Record 24 of Set 14 | aripuana
# Processing Record 25 of Set 14 | kota tinggi
# Processing Record 26 of Set 14 | huarmey
# Processing Record 27 of Set 14 | taoudenni
# Processing Record 28 of Set 14 | bedford
# Processing Record 29 of Set 14 | platanos
# Processing Record 30 of Set 14 | college
# Processing Record 31 of Set 14 | vryburg
# Processing Record 32 of Set 14 | kichera
# Processing Record 33 of Set 14 | banda aceh
# Processing Record 34 of Set 14 | rondonopolis
# Processing Record 35 of Set 14 | lunenburg
# Processing Record 36 of Set 14 | asosa
# Processing Record 37 of Set 14 | port hedland
# Processing Record 38 of Set 14 | burriana
# Processing Record 39 of Set 14 | valledupar
# Processing Record 40 of Set 14 | mayo
# Processing Record 41 of Set 14 | solvychegodsk
# Processing Record 42 of Set 14 | mogapi
# Processing Record 43 of Set 14 | finnsnes
# Processing Record 44 of Set 14 | lucea
# Processing Record 45 of Set 14 | san policarpo
# Processing Record 46 of Set 14 | granada
# Processing Record 47 of Set 14 | sawang daen din
# Processing Record 48 of Set 14 | hapur
# Processing Record 49 of Set 14 | novi troyany
# Processing Record 50 of Set 14 | asyut
# Processing Record 1 of Set 15 | nyagan
# Processing Record 2 of Set 15 | sal rei
# Processing Record 3 of Set 15 | mayumba
# Processing Record 4 of Set 15 | fuyang
# Processing Record 5 of Set 15 | hay river
# Processing Record 6 of Set 15 | gornyy
# Processing Record 7 of Set 15 | necochea
# Processing Record 8 of Set 15 | aljezur
# Processing Record 9 of Set 15 | nuuk
# Processing Record 10 of Set 15 | tombouctou
# Processing Record 11 of Set 15 | bunol
# Processing Record 12 of Set 15 | te anau
# Processing Record 13 of Set 15 | lethem
# Processing Record 14 of Set 15 | algiers
# Processing Record 15 of Set 15 | port hardy
# Processing Record 16 of Set 15 | victoria point
# Processing Record 17 of Set 15 | mao
# Processing Record 18 of Set 15 | burnie
# Processing Record 19 of Set 15 | churachandpur
# Processing Record 20 of Set 15 | katsuura
# Processing Record 21 of Set 15 | bud
# Processing Record 22 of Set 15 | wukari
# Processing Record 23 of Set 15 | mogadishu
# Processing Record 24 of Set 15 | vostok
# Processing Record 25 of Set 15 | cockburn town
# Processing Record 26 of Set 15 | anadyr
# Processing Record 27 of Set 15 | hot springs
# Processing Record 28 of Set 15 | poltavka
# Processing Record 29 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 15 | kulhudhuffushi
# Processing Record 31 of Set 15 | aberdeen
# Processing Record 32 of Set 15 | manado
# Processing Record 33 of Set 15 | cabo rojo
# Processing Record 34 of Set 15 | rantauprapat
# Processing Record 35 of Set 15 | ardakan
# Processing Record 36 of Set 15 | imeni poliny osipenko
# Processing Record 37 of Set 15 | guye
# Processing Record 38 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 15 | cowra
# Processing Record 40 of Set 15 | ciudad bolivar
# Processing Record 41 of Set 15 | darhan
# Processing Record 42 of Set 15 | mangrol
# Processing Record 43 of Set 15 | makokou
# Processing Record 44 of Set 15 | san marcos
# Processing Record 45 of Set 15 | calama
# Processing Record 46 of Set 15 | thabazimbi
# Processing Record 47 of Set 15 | rudraprayag
# Processing Record 48 of Set 15 | guilin
# Processing Record 49 of Set 15 | cumpas
# Processing Record 50 of Set 15 | martapura
# Processing Record 1 of Set 16 | vinh
# Processing Record 2 of Set 16 | yerbogachen
# Processing Record 3 of Set 16 | bom jesus
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Port Alfred -33.59   26.89     65.34        84          23
# 1             Albany  42.60  -73.97     48.99        65          56
# 2  Steamboat Springs  40.48 -106.83     30.20        54           1
# 3          Busselton -33.65  115.33     48.99        94         100
# 4         Mokokchung  26.33   94.53     51.06        81           0
# 5        Mangaratiba -22.96  -44.04     87.80        52           0
# 6              Kapaa  22.08 -159.32     69.80        73          75
# 7               Atar  20.52  -13.05     70.09        33         100
# 8          Sinnamary   5.38  -52.95     83.46        72          99
# 9             Najran  17.49   44.13     73.40        35          40
#
#    Wind Speed Country   Current Description
# 0       12.86      ZA            light rain
# 1        1.99      US         broken clouds
# 2        3.47      US             clear sky
# 3        7.20      AU       overcast clouds
# 4        2.91      IN             clear sky
# 5       11.41      BR             clear sky
# 6        4.70      US         broken clouds
# 7        8.59      MR       overcast clouds
# 8        9.46      GF  heavy intensity rain
# 9        1.54      SA      scattered clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                   City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Port Alfred      ZA -33.59   26.89     65.34        84          23
# 1               Albany      US  42.60  -73.97     48.99        65          56
# 2    Steamboat Springs      US  40.48 -106.83     30.20        54           1
# 3            Busselton      AU -33.65  115.33     48.99        94         100
# 4           Mokokchung      IN  26.33   94.53     51.06        81           0
# ..                 ...     ...    ...     ...       ...       ...         ...
# 684             Cumpas      MX  29.98 -109.78     65.70        24           0
# 685          Martapura      ID  -3.42  114.85     78.80       100          90
# 686               Vinh      VN  18.67  105.67     68.95        85         100
# 687        Yerbogachen      RU  61.28  108.01    -12.91        89          73
# 688          Bom Jesus      BR  -9.07  -44.36     86.85        50         100
#
#      Wind Speed Current Description
# 0         12.86          light rain
# 1          1.99       broken clouds
# 2          3.47           clear sky
# 3          7.20     overcast clouds
# 4          2.91           clear sky
# ..          ...                 ...
# 684        6.58           clear sky
# 685        4.70        thunderstorm
# 686       11.05     overcast clouds
# 687        4.03       broken clouds
# 688        5.66     overcast clouds
#
# [689 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
